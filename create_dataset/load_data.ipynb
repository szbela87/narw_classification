# %%
from scipy.io import arff
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
#os.chdir("/home/szekeres/Dokumentumok/RightWhaleCalls")
# !pwd
# Out:
# /home/szekeres/Dokumentumok/RightWhaleCalls

# %%
SEED = 2023

# %%
# Load ARFF files
data_train, meta = arff.loadarff('RightWhaleCalls_TRAIN.arff')
data_test, meta = arff.loadarff('RightWhaleCalls_TEST.arff')

# %%
#meta

# %%
# Convert to a Pandas DataFrame if needed
df_train = pd.DataFrame(data_train)
df_test = pd.DataFrame(data_test)

# %%
df_train.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.005524 -0.011993  0.005127  0.007996  0.002716  0.000854 -0.009460
# 1 -0.000854  0.001495 -0.004822 -0.000244  0.005432  0.006165 -0.002197
# 2  0.003143  0.004944  0.001160 -0.003540 -0.001343 -0.000885 -0.000763
# 3 -0.001770 -0.001068  0.004425 -0.000977 -0.004242  0.002838  0.001282
# 4  0.008606 -0.001740 -0.003906 -0.003601  0.007263  0.001129 -0.013885
#
#        att8      att9     att10  ...   att3992   att3993   att3994   att3995  \
# 0 -0.005707  0.011993 -0.006012  ...  0.003387  0.002808  0.003967 -0.002380
# 1 -0.010437  0.001282  0.011505  ... -0.002777  0.005615 -0.003510 -0.007477
# 2  0.000122  0.003021 -0.004883  ... -0.004089  0.001312  0.005127 -0.003326
# 3 -0.004303  0.001709 -0.000183  ...  0.000885  0.000183 -0.000763 -0.003296
# 4  0.014160  0.012299 -0.016327  ... -0.000061 -0.004059  0.002625  0.005310
#
#     att3996   att3997   att3998   att3999   att4000          class
# ...

# %%
targets = df_train['class'].unique()
targets
# Out:
# array([b'RightWhale', b'NoWhale'], dtype=object)

# %%
target_values_dict = {}
for i, name in enumerate(targets):
    target_values_dict[name] = i

# %%
target_values_dict
# Out:
# {b'RightWhale': 0, b'NoWhale': 1}

# %%
df_train["class"] = df_train["class"].replace(target_values_dict)
df_test["class"] = df_test["class"].replace(target_values_dict)
df_train.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.005524 -0.011993  0.005127  0.007996  0.002716  0.000854 -0.009460
# 1 -0.000854  0.001495 -0.004822 -0.000244  0.005432  0.006165 -0.002197
# 2  0.003143  0.004944  0.001160 -0.003540 -0.001343 -0.000885 -0.000763
# 3 -0.001770 -0.001068  0.004425 -0.000977 -0.004242  0.002838  0.001282
# 4  0.008606 -0.001740 -0.003906 -0.003601  0.007263  0.001129 -0.013885
#
#        att8      att9     att10  ...   att3992   att3993   att3994   att3995  \
# 0 -0.005707  0.011993 -0.006012  ...  0.003387  0.002808  0.003967 -0.002380
# 1 -0.010437  0.001282  0.011505  ... -0.002777  0.005615 -0.003510 -0.007477
# 2  0.000122  0.003021 -0.004883  ... -0.004089  0.001312  0.005127 -0.003326
# 3 -0.004303  0.001709 -0.000183  ...  0.000885  0.000183 -0.000763 -0.003296
# 4  0.014160  0.012299 -0.016327  ... -0.000061 -0.004059  0.002625  0.005310
#
#     att3996   att3997   att3998   att3999   att4000  class
# ...

# %%
len(df_train), len(df_test)
# Out:
# (10934, 1962)

# %%
df = pd.concat([df_train, df_test], ignore_index=True)

# %%
len(df)
# Out:
# 12896

# %%
df_train, df_test = train_test_split(df, stratify = df["class"], test_size = 0.2, random_state = SEED)

# %%
df_train
# Out:
#            att1      att2      att3      att4      att5      att6      att7  \
# 8785  -0.000702  0.001282  0.007324  0.001770 -0.000488 -0.001953 -0.005615
# 7077   0.160553 -0.101440 -0.265564  0.009491  0.116974  0.060944  0.023956
# 10994  0.009918 -0.004669 -0.004547  0.001343 -0.012970 -0.000488  0.008240
# 12364 -0.014679  0.007599 -0.000214  0.003937 -0.003876 -0.004517 -0.005219
# 942   -0.000458  0.019775  0.004578 -0.012604  0.000641 -0.002350  0.016327
# ...         ...       ...       ...       ...       ...       ...       ...
# 9230   0.004211 -0.001495 -0.004425  0.005890 -0.011658 -0.004639  0.012207
# 3916  -0.005188 -0.003418  0.014862 -0.007660 -0.002808  0.005829 -0.008514
# 11322 -0.008118  0.003235  0.000153 -0.004822  0.006378  0.005524 -0.008942
# 11454  0.000946  0.004791  0.005615  0.003754  0.000275 -0.003052 -0.004242
# 8890   0.019073 -0.023499 -0.000153  0.006287 -0.036499  0.029419  0.012512
#
# ...

# %%
df_train.to_csv("train_whales.csv",sep=",",index=False)
df_test.to_csv("test_whales.csv",sep=",",index=False)

# %%
len(df_train),len(df_test)
# Out:
# (10316, 2580)

# %%
len(df_train)*0.25
# Out:
# 2579.0
